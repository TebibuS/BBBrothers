# %%
from dotenv import load_dotenv
import os
import pandas as pd
import requests
from datetime import datetime

ENV_PATH = str('C:\BBBrothers\BBB BETTER AND BETTER FILES\.env')
load_dotenv(dotenv_path=ENV_PATH)
# Out:
# True

# %%
def get_business_details(api_key, business_name,location="Minnesota"):
    url = f"https://maps.googleapis.com/maps/api/place/textsearch/json?query={business_name}+in+{location}&key={api_key}"
    response = requests.get(url)
    data = response.json()

    business_details_list = []

    if 'results' in data:
        for result in data['results']:
            place_id = result['place_id']
            details_url = f"https://maps.googleapis.com/maps/api/place/details/json?place_id={place_id}&fields=name,formatted_phone_number,formatted_address,website,reviews,rating&key={api_key}"
            details_response = requests.get(details_url)
            details_data = details_response.json()
            
            if 'result' in details_data:
                last_reviewed = max([review.get('time', 0) for review in details_data['result'].get('reviews', [{'time': 0}])])
                last_reviewed_date = datetime.utcfromtimestamp(last_reviewed).strftime('%Y-%m-%d %H:%M:%S')
                
                business_info = {
                    'Name': details_data['result'].get('name', ''),
                    'Phone Number': details_data['result'].get('formatted_phone_number', ''),
                    'Address': details_data['result'].get('formatted_address', ''),
                    'Website': details_data['result'].get('website', ''),
                    'Last Reviewed': last_reviewed_date,
                    'Rating' : details_data['result'].get('rating','')
                }
                business_details_list.append(business_info)
    if business_details_list:
        df = pd.DataFrame(business_details_list)
        return df
    else:
        return pd.DataFrame({'Error': ['No businesses found.']})

# %%
# Example usage
api_key = os.getenv("GOOGLE_PLACES_TOKEN")
business_name = "Starbucks"
business_details_df = get_business_details(api_key, business_name)

# %%
business_details_df
# Out:
#                 Name    Phone Number  \
# 0          Starbucks  (507) 389-2812
# 1          Starbucks  (507) 625-9070
# 2          Starbucks  (507) 625-8900
# 3   Starbucks Coffee  (507) 995-0260
# 4          Starbucks  (507) 625-1011
# 5          Starbucks  (952) 938-3604
# 6          Starbucks  (507) 283-7533
# 7          Starbucks  (612) 240-6653
# 8          Starbucks  (507) 645-4777
# 9          Starbucks  (952) 935-9641
# 10         Starbucks  (763) 767-6833
# 11         Starbucks  (507) 451-1882
# 12         Starbucks  (612) 378-7765
# 13         Starbucks  (507) 455-3624
# 14         Starbucks  (651) 356-2678
# 15         Starbucks  (952) 440-2314
# 16         Starbucks  (612) 716-2225
# 17         Starbucks  (612) 374-5168
# 18         Starbucks  (651) 423-7112
# 19         Starbucks  (612) 625-2037
#
#                                               Address  \
# 0   7 Centennial Student Union, Mankato, MN 56001,...
# 1               2010 Adams St, Mankato, MN 56001, USA
# 2            1872 Madison Ave, Mankato, MN 56001, USA
# 3     1002 Old Minnesota Ave, St Peter, MN 56082, USA
# 4               1850 Adams St, Mankato, MN 56001, USA
# 5                   1505 MN-7, Hopkins, MN 55305, USA
# 6       1715 Lor Ray Dr, North Mankato, MN 56003, USA
# 7                19285 MN-7, Shorewood, MN 55331, USA
# 8          2323 2nd Ave NW, Northfield, MN 55057, USA
# 9             8900 MN-7, St Louis Park, MN 55426, USA
# 10      1384 109th Ave NE, Minneapolis, MN 55434, USA
# 11               301 Park Dr, Owatonna, MN 55060, USA
# 12  The Graduate Hotel, 615 Washington Ave SE, Min...
# 13           641 W Bridge St, Owatonna, MN 55060, USA
# 14       100 Hennepin Ave, Minneapolis, MN 55401, USA
# 15         13945 Frontage Road, Savage, MN 55378, USA
# 16              11129 Hwy 55, Plymouth, MN 55441, USA
# 17      2212 Hennepin Ave, Minneapolis, MN 55405, USA
# 18     14903 S Robert Trail, Rosemount, MN 55068, USA
# 19  300 Washington Ave SE, Minneapolis, MN 55455, USA
#
#                                               Website        Last Reviewed  \
# 0   https://www.starbucks.com/store-locator/store/...  2023-10-25 19:30:09
# 1   https://www.starbucks.com/store-locator/store/...  2024-01-31 15:14:36
# 2   https://www.starbucks.com/store-locator/store/...  2023-12-06 15:40:20
# 3             https://www.starbucks.com/store-locator  2024-01-20 20:59:19
# 4   https://www.starbucks.com/store-locator/store/...  2023-12-28 16:16:01
# 5   https://www.starbucks.com/store-locator/store/...  2023-12-31 19:12:52
# 6                                                      2024-02-09 04:59:15
# 7   https://www.starbucks.com/store-locator/store/...  2023-12-23 16:58:48
# 8   https://www.starbucks.com/store-locator/store/...  2023-12-16 18:03:02
# 9   https://www.starbucks.com/store-locator/store/...  2023-12-01 06:29:50
# 10  https://www.starbucks.com/store-locator/store/...  2023-11-17 02:41:33
# 11  https://www.starbucks.com/store-locator/store/...  2024-02-03 04:37:31
# 12  https://www.starbucks.com/store-locator/store/...  2023-12-27 16:11:33
# 13  https://www.starbucks.com/store-locator/store/...  2024-01-20 18:31:15
# 14  https://www.starbucks.com/store-locator/store/...  2024-02-16 18:45:02
# 15  https://www.starbucks.com/store-locator/store/...  2024-02-10 21:12:01
# 16  https://www.starbucks.com/store-locator/store/...  2023-11-09 21:30:10
# 17  https://www.starbucks.com/store-locator/store/...  2023-08-28 16:28:49
# 18  https://www.starbucks.com/store-locator/store/...  2024-01-21 15:06:38
# 19  https://www.starbucks.com/store-locator/store/...  2024-02-09 18:14:41
#
#     Rating
# 0      2.3
# 1      3.8
# 2      4.3
# 3      4.0
# 4      4.0
# 5      4.0
# 6      4.5
# 7      3.8
# 8      4.0
# 9      2.9
# 10     4.2
# 11     4.2
# 12     4.2
# 13     4.1
# 14     4.3
# 15     4.2
# 16     3.8
# 17     4.2
# 18     4.1
# 19     3.8

# %%
business_details_df.to_csv('example_google_places_data.csv')
